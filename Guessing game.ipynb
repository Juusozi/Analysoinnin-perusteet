# %%
name = "Juuso"

guess = input("Guess the name: ") 

if guess == name:
    print("Conratulations!")
else:
    print("Wrong name, try again!")
# Out:
# Wrong name, try again!

# %%
name = "Juuso"

guess = ""

while guess != name:
    guess = input("Guess the name: ")

print("Conratulations!")
# Out:
# Conratulations!
